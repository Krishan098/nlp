# %%
from __future__ import division
import nltk,re,pprint

# %%
from urllib.request import urlopen
url='https://www.gutenberg.org/files/2554/2554-0.txt'
raw=urlopen(url).read()
text=raw.decode('utf-8')
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 1135214

# %%
raw[:75]
# Out:
# b'*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %% [markdown]
# *Processing:*
#
#
# 1) tokenization: a list of words and punctuation.

# %%
tokens=nltk.word_tokenize(text)
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 253688

# %%
tokens[1020:1060]
# Out:
# ['obliged',
#  'to',
#  'pass',
#  'her',
#  'kitchen',
#  ',',
#  'the',
#  'door',
#  'of',
#  'which',
#  'invariably',
#  'stood',
#  'open',
#  '.',
#  'And',
#  'each',
#  'time',
#  'he',
#  'passed',
#  ',',
#  'the',
#  'young',
#  'man',
#  'had',
#  'a',
#  'sick',
#  ',',
#  'frightened',
#  'feeling',
#  ',',
#  'which',
#  'made',
#  'him',
#  'scowl',
#  'and',
#  'feel',
#  'ashamed',
#  '.',
#  'He',
#  'was']

# %%
text_=nltk.Text(tokens)
type(text_)
# Out:
# nltk.text.Text

# %%
text_[1020:1060]
# Out:
# ['obliged',
#  'to',
#  'pass',
#  'her',
#  'kitchen',
#  ',',
#  'the',
#  'door',
#  'of',
#  'which',
#  'invariably',
#  'stood',
#  'open',
#  '.',
#  'And',
#  'each',
#  'time',
#  'he',
#  'passed',
#  ',',
#  'the',
#  'young',
#  'man',
#  'had',
#  'a',
#  'sick',
#  ',',
#  'frightened',
#  'feeling',
#  ',',
#  'which',
#  'made',
#  'him',
#  'scowl',
#  'and',
#  'feel',
#  'ashamed',
#  '.',
#  'He',
#  'was']

# %%
text_.collocations()
# Out:
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Porfiry Petrovitch; Amalia Ivanovna; great deal; young man;
# Nikodim Fomitch; Ilya Petrovitch; Andrey Semyonovitch; Hay Market;
# Dmitri Prokofitch; Good heavens; police station; head clerk

# %%
text.find("PART I")
# Out:
# 4638

# %%
text.rfind("End of Project Gutenberg's Crime")
# Out:
# -1

# %%
text=text[4638:-1]

# %%
text.find("PART I")
# Out:
# 0

# %%
url="http://news.bbc.co.uk/2/hi/health/2284783.stm"
html=urlopen(url).read().decode('utf-8')
html[:60]
type(html)
# Out:
# str

# %%
print(html)
# Out:
# <!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
# <html>
# <head>
# <title>BBC NEWS | Health | Blondes 'to die out in 200 years'</title>
# <meta name="keywords" content="BBC, News, BBC News, news online, world, uk, international, foreign, british, online, service">
# <meta name="OriginalPublicationDate" content="2002/09/27 11:51:55">
# <meta name="UKFS_URL" content="/1/hi/health/2284783.stm">
# <meta name="IFS_URL" content="/2/hi/health/2284783.stm">
# <meta name="HTTP-EQUIV" content="text/html;charset=iso-8859-1">
# <meta name="Headline" content="Blondes 'to die out in 200 years'">
# <meta name="Section" content="Health">
# <meta name="Description" content="Natural blondes are an endangered species and will die out by 2202, a study suggests.">
# <!-- GENMaps-->
# <map name="banner">
# <area alt="BBC NEWS" coords="7,9,167,32" href="http://news.bbc.co.uk/1/hi.html" shape="RECT">
# </map>
#
# ...

# %%
from bs4 import BeautifulSoup
soup= BeautifulSoup(html,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
# <html>
#  <head>
#   <title>
#    BBC NEWS | Health | Blondes 'to die out in 200 years'
#   </title>
#   <meta content="BBC, News, BBC News, news online, world, uk, international, foreign, british, online, service" name="keywords"/>
#   <meta content="2002/09/27 11:51:55" name="OriginalPublicationDate"/>
#   <meta content="/1/hi/health/2284783.stm" name="UKFS_URL"/>
#   <meta content="/2/hi/health/2284783.stm" name="IFS_URL"/>
#   <meta content="text/html;charset=iso-8859-1" name="HTTP-EQUIV"/>
#   <meta content="Blondes 'to die out in 200 years'" name="Headline"/>
#   <meta content="Health" name="Section"/>
#   <meta content="Natural blondes are an endangered species and will die out by 2202, a study suggests." name="Description"/>
#   <!-- GENMaps-->
#   <map name="banner">
#    <area alt="BBC NEWS" coords="7,9,167,32" href="http://news.bbc.co.uk/1/hi.html" shape="RECT"/>
# ...

# %%
raw=soup.get_text()
tokens=nltk.word_tokenize(raw)

# %%
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
tokens=tokens[96:399]
text=nltk.Text(tokens)
text.concordance('gene')
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %%
'''SHORTCOMINGS FOR A SEARCH ENGINE:
        o> the allowable range of search patterns is severely restricted.
        search engines only allow us to search for individual words or strings of words, sometimes with wildcards.
        o> they give inconsistent results and can give widely different figures when used at different times or in different geographical regions. 
        o> the markup in the results returned by a search engine may change unpredictably, breaking any pattern-based method of a locating particular content.
'''
# Out:
# 'SHORTCOMINGS FOR A SEARCH ENGINE:\n        o> the allowable range of search patterns is severely restricted.\n        search engines only allow us to search for individual words or strings of words, sometimes with wildcards.\n        o> they give inconsistent results and can give widely different figures when used at different times or in different geographical regions. \n        o> the markup in the results returned by a search engine may change unpredictably, breaking any pattern-based method of a locating particular content.\n'

# %%
'''PROCESSING RSS FEEDS'''
import feedparser
llog=feedparser.parse("c")

# %%
len(llog.entries)
# Out:
# 0

# %%
post.title
# Out:
# 'Replicate evolve the image&#8230;'

# %%
content=post.content[0].value

# %%
content[:70]
# Out:
# '<p>From <a href="https://www.reddit.com/r/ChatGPT/comments/1kbj71z/i_t'

# %%
soup=BeautifulSoup(content,'html.parser')
clean_text=soup.get_text()
tokens=nltk.word_tokenize(clean_text)
print(tokens[:20])
# Out:
# ['From', 'r/chatgpt', ':', 'I', 'tried', 'the', '``', 'Create', 'the', 'exact', 'replica', 'of', 'this', 'image', ',', 'do', "n't", 'change', 'a', 'thing']

# %%
import os
os.listdir('.')
# Out:
# ['.git',
#  '.gitignore',
#  '.python-version',
#  '.ruff_cache',
#  '.venv',
#  'main.py',
#  'NLTK_Bird_Klein_Loper.pdf',
#  'processingrawtext.ipynb',
#  'pyproject.toml',
#  'README.md',
#  'start.ipynb',
#  'start.py',
#  'textcorpora.ipynb',
#  'uv.lock']

# %%
s=input("Enter some text:")

# %%
print('You typed ',len(nltk.word_tokenize(s)),"words")
# Out:
# You typed  8 words

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''Text processing with Unicode
    unicode supports over a million characters. Each character is assigned a number, called a code point.
    uXXXX, where XXXX is th e number in four-digit hexadicaml form
    
    Translation into Unicode is called decoding. 
    Conversely, translation out of Unicode is called encoding.
'''
# Out:
# 'Text processing with Unicode\n    unicode supports over a million characters. Each character is assigned a number, called a code point.\n    uXXXX, where XXXX is th e number in four-digit hexadicaml form\n    \n    Translation into Unicode is called decoding. \n    Conversely, translation out of Unicode is called encoding.\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''characters are abstract entities that can be reaised as one or more glyphs..
A font is a mapping from characters to glyphs.
'''
# Out:
# 'characters are abstract entities that can be reaised as one or more glyphs..\nA font is a mapping from characters to glyphs.\n'

# %%
import codecs
path=nltk.data.find('corpora/unicode_samples/polish-lat2.txt')
f=codecs.open(path,encoding='latin2')

# %%
f=codecs.open(path,'r',encoding='utf-8')

# %%
for line in f:
    line=line.strip()
    print(line.encode('unicode_escape'))

# %%
print(line.encode('unicode_escape') for line in f)
# Out:
# <generator object <genexpr> at 0x00000187BC48A880>

# %%
#integer ordinal of a character
ord('a')
# Out:
# 97

# %%
a=u'\u0061'

# %%
a
# Out:
# 'a'

# %%
import unicodedata#let's us inspect the  properties of Unicode characters.
lines=codecs.open(path,encoding='latin2').readlines()
line=lines[2]
print(line.encode('unicode_escape'))

# %% [markdown]
# *Regular Expressions for detecting Word Patterns*

# %%
import re
wordlist=[w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
[w for w in wordlist if re.search('ed$',w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
# ? symbol specifies that the previous character is optional.
'''Ranges and closures:
    The T9 system is used for entering text on mobile phones. 
    two or more words that are entered with the same sequence of keystrokes are known as textonyms.
'''
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$',w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']
